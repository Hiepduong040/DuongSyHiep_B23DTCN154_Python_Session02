# %%
# bai 1:
number = int(input("Nhap mot so nguyen"))
if number <0:
    print(f"day la so am")
else: print("day la so duong")
# Out:
# day la so duong

# %%
# bai 2:
number = int(input("nhap mot so nguyen"))
if number // 2 : 
    print("ban vua nhap so chan")
else :
    print("ban vua nhap so le")
# Out:
# ban vua nhap so chan

# %%
# Nhập số nguyên dương n từ người dùng
n = int(input("Nhập một số nguyên dương n: "))

# Kiểm tra xem n có phải là số nguyên dương không
if n < 0:
    print("Vui lòng nhập một số nguyên dương.")
else:
    # Tính giai thừa n!
    factorial = 1
    for i in range(1, n + 1):
        factorial *= i
    
    # In ra kết quả
    print(f"{n}! = {factorial}")
# Out:
# 3! = 6

# %%
#bai 3:
number = int(input("nhap mot so nguyen"))

if (number % 3 == 0  ) and (number  % 5 == 0  ):
    print("ban vua nhap so chia het cho 3 va 5")
elif number  % 3 == 0:
    print("ban vua nhap so chia het cho 3")
elif number % 5 == 0:
    print("ban vua nhap so chia het cho 5")
else:
    print("so ban vua nhap khong chia het cho 3 va 5")
# Out:
# so ban vua nhap khong chia het cho 3 va 5

# %%
#bai 4:
number = int(input("nhap vao so nguyen duong"))
count = 0
if number > 0:
    for i in range(1,number+1):
        count += i
    print(f"tong cac so tu 0 den {number} la: {count}")
else: 
    print("so vua nhap khong phai so nguyen duong")

# %%
# bai 5:
n = int(input("Nhập số nguyên dương n: "))

if n > 0:
    so_goc = n
    so_dao = 0
    
    while n > 0:
        chu_so = n % 10             # Lấy chữ số cuối
        so_dao = so_dao * 10 + chu_so  # Thêm vào số đảo
        n = n // 10                 # Bỏ chữ số cuối
    
    if so_goc == so_dao:
        print(f"{so_goc} là số đối xứng.")
    else:
        print(f"{so_goc} không phải số đối xứng.")
else:
    print("Vui lòng nhập số nguyên dương!")

# %%
#bài 6:

n = int(input("Nhập một số nguyên dương n: "))

if n < 0:
    print("Vui lòng nhập một số nguyên dương.")
else:
    factorial = 1
    for i in range(1, n + 1):
        factorial *= i
    
    print(f"{n}! = {factorial}")

# %%
#Bài 7:
def is_prime(num):
    """Kiểm tra xem số num có phải là số nguyên tố không."""
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

# Nhập hai số nguyên a và b từ người dùng
a = int(input("Nhập số nguyên a: "))
b = int(input("Nhập số nguyên b: "))

# Đảm bảo a là nhỏ hơn hoặc bằng b
if a > b:
    a, b = b, a  

print(f"Các số nguyên tố trong khoảng [{a}, {b}] là:")
for number in range(a, b + 1):
    if is_prime(number):
        print(number, end=' ')

# %%
#bai 8
a = int(input("Nhập cạnh a: "))
b = int(input("Nhập cạnh b: "))
c = int(input("Nhập cạnh c: "))

if a + b > c and a + c > b and b + c > a:
    print("La 3 canh tam giac")
else:
    print("Khong phai 3 canh tam giac")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #bai 8
# ----> 2 a = int(input("Nhập cạnh a: "))
#       3 b = int(input("Nhập cạnh b: "))
#       4 c = int(input("Nhập cạnh c: "))
#
# ValueError: invalid literal for int() with base 10: '3; 4; 5'
